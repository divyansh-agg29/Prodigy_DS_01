# %% [markdown]
# <h1>Exploring Global Trends with World Bank Data</h1>
#
# In this project, we delve into global trends by analyzing data sourced from the World Bank website. We focus on crucial indicators such as world population, gender ratio, and working-class ratio. Leveraging the power of Python libraries like pandas for data manipulation and matplotlib for visualization, we embark on a journey of data exploration and analysis. This project involves various tasks including data cleaning, preprocessing, and merging disparate datasets to derive meaningful insights. Through visualization techniques, we aim to uncover patterns and trends factors on a global scale.
#
# The dataset can be downloaded at the <a href="https://data.worldbank.org/">website</a> of the World Bank.<br>

# %% [markdown]
# <h2>Importing Libraries and the Data</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
df_1 = pd.read_csv("total_population.csv")
df_2 = pd.read_csv("female_percentage.csv")
df_3 = pd.read_csv("working_age_population_percentage.csv")

# %%
df_1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df_2.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                Indicator Name     Indicator Code       1960  \
# 0  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.858849
# 1  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.387880
# 2  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 3  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.179683
# 4  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  49.843790
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  50.850191  50.845065  50.836016  50.826773  50.823381  ...  52.515590
# 1  50.388814  50.391276  50.395656  50.400512  50.405510  ...  50.559167
# ...

# %%
df_3.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                   Indicator Name     Indicator Code  \
# 0  Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 1  Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 2  Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 3  Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 4  Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0  54.495678  54.588701  54.585630  54.674206  54.873448  55.181477  ...
# 1  52.827416  52.760490  52.682676  52.586510  52.485520  52.376628  ...
# ...

# %% [markdown]
# <h2>Data Cleaning</h2>

# %% [markdown]
# First we remove all rows except the ones with country as the 'World'

# %%
df_1 = df_1[ df_1["Country Name"].isin(["World"]) ] 
df_2 = df_2[ df_2["Country Name"].isin(["World"]) ]
df_3 = df_3[ df_3["Country Name"].isin(["World"]) ]

# %% [markdown]
# We remove extranious columns

# %%
df_1.drop(columns=['Country Name','Country Code','Indicator Name','Indicator Code','Unnamed: 67'], inplace=True)
df_2.drop(columns=['Country Name','Country Code','Indicator Name','Indicator Code','Unnamed: 67'], inplace=True)
df_3.drop(columns=['Country Name','Country Code','Indicator Name','Indicator Code','Unnamed: 67'], inplace=True)

# %% [markdown]
# Sample data after cleaning steps:

# %%
df_1.head()
# Out:
#              1960          1961          1962          1963          1964  \
# 259  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#              1965          1966          1967          1968          1969  \
# 259  3.328209e+09  3.398480e+09  3.468371e+09  3.540164e+09  3.614573e+09
#
#      ...          2013          2014          2015          2016  \
# 259  ...  7.229303e+09  7.317040e+09  7.403850e+09  7.490415e+09
#
#              2017          2018          2019          2020          2021  \
# 259  7.576442e+09  7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09
#
#              2022
# 259  7.950947e+09
#
# [1 rows x 63 columns]

# %%
df_1.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %% [markdown]
# Now we will merge the three seperate dataframes into one to ease our later processes

# %%
df_1 = pd.melt(df_1, var_name='Year', value_name='Population')
df_1['Year'] = df_1['Year'].astype(int)

df_2 = pd.melt(df_2, var_name='Year', value_name='Female Ratio')
df_2['Year'] = df_2['Year'].astype(int)

df_3 = pd.melt(df_3, var_name='Year', value_name='Working Age Ratio')
df_3['Year'] = df_3['Year'].astype(int)

# %%
df = df_1.copy()
df['Female Ratio'] = df_2['Female Ratio']
df['Working Age Ratio'] = df_3['Working Age Ratio']
df
# Out:
#     Year    Population  Female Ratio  Working Age Ratio
# 0   1960  3.031474e+09     50.028945          57.609640
# 1   1961  3.072422e+09     50.029363          57.514865
# 2   1962  3.126850e+09     50.023850          57.396888
# 3   1963  3.193429e+09     50.012827          57.171011
# 4   1964  3.260442e+09     50.002260          56.978786
# ..   ...           ...           ...                ...
# 58  2018  7.660371e+09     49.684689          64.966738
# 59  2019  7.741775e+09     49.691859          64.909016
# 60  2020  7.820206e+09     49.705180          64.875490
# 61  2021  7.888306e+09     49.722324          64.887545
# 62  2022  7.950947e+09     49.735282          64.916530
#
# [63 rows x 4 columns]

# %% [markdown]
# <h2>Data Visualization</h2>

# %%
plt.figure(figsize=(6,4))
plt.plot(df['Year'],df['Population']/(10**9))
plt.xlabel('Year',fontsize=12)
plt.ylabel('World Population (in Billions)')
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.ylim(55,70)
plt.xlabel('Year',fontsize=12)
plt.ylabel('Percentage of Working Class People')
plt.plot(df['Year'],df['Working Age Ratio'],color="blue",linewidth=2)


plt.subplot(1,2,2)
plt.ylim(49.6,50.2)
plt.xlabel('Year',fontsize=12)
plt.ylabel('Percentage of Females')
plt.plot(df['Year'],df['Female Ratio'],color="red",linewidth=2)
plt.plot(df['Year'],[50]*63,color="white",linestyle="dotted",linewidth=1)
plt.show()
